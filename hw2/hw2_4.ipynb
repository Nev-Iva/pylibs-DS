# %%
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
# %config InlineBackend.figure_format = 'svg'

# %%
plt.style.use('fivethirtyeight')

# %%
url = 'creditcard.csv'

# %%
ds_cc = pd.read_csv(url)

# %%
ds_cc_vc = ds_cc['Class'].value_counts()
ds_cc_vc
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %%
ds_cc_vc.plot(kind = 'bar')
plt.show()

# %%
ds_cc_vc.plot(kind = 'bar', logy = True)
plt.show()
